# %%
import pandas as pd

df=pd.read_csv('publications.csv')
df.head()
# Out:
#                                            Автор (ы)  \
# 0            Erzurumlu, Y.; Dogan, H.K.; Çatakli, D.
# 1                      Tan, G.; Özkan, G.; Aydin, E.
# 2  Ibrahim, B.; Reis, A.; Arın, U.E.; Muhammed, M...
# 3  Kadyrov, S.; Kayumova, G.; Yallaboyev, A.; Sag...
# 4  KHAZIMOV, K.; Zhumagaliyev, Y.; Khazimov, Z.; ...
#
#                                    Author full names  \
# 0  Erzurumlu, Yalcin (55588677300); Dogan, Hatice...
# 1  Tan, Gözdenur (59648729400); Özkan, Gülcan (70...
# 2  Ibrahim, Bashar M.S. (59712349500); Reis, Ahu ...
# 3  Kadyrov, Shirali (36844229300); Kayumova, Gauh...
# 4  KHAZIMOV, Kanat M. (56469755000); Zhumagaliyev...
#
#                             Идентификатор автора(ов)  \
# 0              55588677300; 57290684200; 57811442500
# 1               59648729400; 7003718004; 56946415500
# 2  59712349500; 55964741200; 58981860600; 5720412...
# 3  36844229300; 60168405000; 60168438300; 6016826...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754 entries, 0 to 753
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Автор (ы)                      754 non-null    object
#  1   Author full names              754 non-null    object
#  2   Идентификатор автора(ов)       754 non-null    object
#  3   Название документа             754 non-null    object
#  4   Год                            754 non-null    int64
#  5   Название источника             754 non-null    object
#  6   Том                            571 non-null    object
#  7   Выпуск                         466 non-null    object
#  8   Статья №                       225 non-null    object
#  9   Страница начала                467 non-null    object
#  10  Страница окончания             466 non-null    object
#  11  Цитирования                    754 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['Автор (ы)', 'Author full names', 'Идентификатор автора(ов)',
#        'Название документа', 'Год', 'Название источника', 'Том', 'Выпуск',
#        'Статья №', 'Страница начала', 'Страница окончания', 'Цитирования',
#        'DOI', 'Ссылка', 'Организации', 'Авторы организаций',
#        'Краткое описание', 'Ключевые слова автора', 'Ключевые слова указателя',
#        'Сведения о финансировании', 'Текст о финансировании', 'Спонсоры',
#        'Название конференции', 'Дата конференции',
#        'Место проведения конференции', 'Код конференции', 'Тип документа',
#        'СТАДИЯ ПУБЛИКАЦИИ', 'Open Access (открытый доступ)', 'Источник', 'EID',
#        'subject_area'],
#       dtype='object')

# %%
df['subject_area'].isna().sum()
# Out:
# np.int64(0)
