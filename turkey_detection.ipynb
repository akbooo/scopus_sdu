# %%
import pandas as pd

# %%
df=pd.read_csv("publications.csv")
tf=df[df['Организации'].str.contains("isparta", case=False, na=False)]
tf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 2 to 751
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Автор (ы)                      15 non-null     object
#  1   Author full names              15 non-null     object
#  2   Идентификатор автора(ов)       15 non-null     object
#  3   Название документа             15 non-null     object
#  4   Год                            15 non-null     int64
#  5   Название источника             15 non-null     object
#  6   Том                            13 non-null     object
#  7   Выпуск                         13 non-null     object
#  8   Статья №                       4 non-null      object
#  9   Страница начала                11 non-null     object
#  10  Страница окончания             10 non-null     object
#  11  Цитирования                    15 non-null     int64
# ...

# %%
tf['Организации'].value_counts()
# Out:
# Организации
# ...

# %%
tf['Автор (ы)'].to_list()
# Out:
# ['Katsanevakis, S.; Acar, Ü.; Ammar, I.; Balci, B.A.; Bekas, P.; Belmonte, M.; Chintiroglou, C.C.; Consoli, P.; Dimiza, M.; Fryganiotis, K.; Gerovasileiou, V.; Gnisci, V.; Gülşahin, N.; Hoffman, R.; Issaris, Y.; Izquierdo-Gomez, D.; Izquierdo-Muñoz, A.; Kavadas, S.; Koehler, L.; Konstantinidis, E.; Mazza, G.; Nowell, G.; Önal, U.; Özen, M.R.; Pafilis, P.; Pastore, M.; Perdikaris, C.; Poursanidis, D.; Prato, E.; Russo, F.; Sicuro, B.; Tarkan, A.N.; Thessalou-Legaki, M.; Tiralongo, F.; Triantaphyllou, M.; Tsiamis, K.; Tunçer, S.; Turan, C.; Türker, A.; Yapici, S.']

# %%
tf['Организации'].to_list()
# Out:
# ['Department of Pharmaceutical Microbiology, Süleyman Demirel Üniversitesi, Isparta, Isparta, Turkey; Department of Microbiology, Karadeniz Technical University, Trabzon, Trabzon, Turkey; Vocational School of Health Services, Süleyman Demirel Üniversitesi, Isparta, Isparta, Turkey; Department of Pharmaceutical Chemistry, SDU University, Kaskelen, Almaty, Kazakhstan',
#  'Department of Thoracic Surgery, SDU University, Kaskelen, Almaty, Kazakhstan; Department of Pharmacology, Süleyman Demirel University, Faculty of Medicine, Isparta, Turkey; Department of Bioengineering, Süleyman Demirel Üniversitesi, Isparta, Isparta, Turkey; Department of Pathology, Burdur Mehmet Akif Ersoy Üniversitesi, Burdur, Turkey; Department of Electronics and Communication Engineering, SDU University, Kaskelen, Almaty, Kazakhstan',
# ...

# %%
both_mask = (
    df["Организации"].str.contains("kaskelen", case=False, na=False)
    &
    df["Организации"].str.contains("turkey|isparta", case=False, na=False)
)

both_count = both_mask.sum()
print("Records with BOTH Kaskelen and Turkey:", both_count)
# Out:
# Records with BOTH Kaskelen and Turkey: 70

# %%
both_mask.head(


    
)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: Организации, dtype: bool
