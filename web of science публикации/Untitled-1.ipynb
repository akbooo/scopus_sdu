# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Subbota\\scopus\\рез.csv")
print(df["Автор (ы)"].dropna().apply(lambda x: [a.strip() for a in str(x).split(";")]).explode().nunique())
# Out:
# 1311

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\Subbota\\scopus\\рез.csv")

authors = (
    df["Автор (ы)"]
    .dropna()
    .str.split(";")
    .explode()
    .str.strip()
)

print("Unique authors:", authors.nunique())
# Out:
# Unique authors: 1311

# %%
df['Author full names'].head()
# Out:
# 0    Kadyrov, Shirali (36844229300); Kayumova, Gauh...
# 1    KHAZIMOV, Kanat M. (56469755000); Zhumagaliyev...
# 2    Bolatova, Diana (57994589600); Kadyrov, Shiral...
# 3    Kadyrov, Shirali (36844229300); Orynbassar, Al...
# 4    Yegorov, Sergey (26434035900); Bromage, Sabri ...
# Name: Author full names, dtype: object

# %%
authors.value_counts().head(30)
# Out:
# Автор (ы)
# Kadyrov, S.           43
# Turan, C.             26
# Balta, N.             23
# Saydaliev, H.B.       22
# Amirgaliyev, Y.       22
# Dzhumadil'daev, A.    20
# Serek, A.             19
# Alimanova, M.         19
# Zhaparov, M.          17
# Baimuratov, O.        14
# Sartayev, B.K.        14
# Mashurov, F.          14
# Bogdanchikov, A.      14
# Omarov, B.            14
# Orynbassar, A.        13
# Yessirkegenov, N.     11
# Sadyk, U.             11
# Dinara, D.            10
# Mirzoyeva, L.Y.        9
# Ismailov, N.           9
# Zhussipbek, G.         9
# Oskenbayev, Y.         9
# Japashov, N.           9
# Yegorov, S.            8
# Kozhakhmet, S.         8
# Shynarbek, N.          8
# Mamatnabiyev, Z.       8
# Aitchanov, B.          7
# Sapazhanov, Y.         7
# Moldashev, K.          7
# Name: count, dtype: int64
