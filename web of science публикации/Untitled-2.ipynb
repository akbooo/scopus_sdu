# %%
import pandas as pd
df=pd.read_excel('savedrecs.xls')
df1=pd.read_excel('savedrecs1.xls')
df2=pd.read_excel('savedrecs2.xls')
df3=pd.read_excel('savedrecs3.xls')
df4=pd.read_excel('savedrecs4.xls')
df5=pd.read_excel('savedrecs5.xls')
df6=pd.read_excel('savedrecs6.xls')
df7=pd.read_excel('savedrecs7.xls')
df8=pd.read_excel('savedrecs8.xls')
df9=pd.read_excel('savedrecs9.xls')
df10=pd.read_excel('savedrecs10.xls')
df11=pd.read_excel('savedrecs11.xls')
df12=pd.read_excel('savedrecs12.xls')
df13=pd.read_excel('savedrecs13.xls')
df125=pd.read_excel('savedrecs125.xls')
df126=pd.read_excel('savedrecs126.xls')
df137=pd.read_excel('savedrecs137.xls')
df14=pd.read_excel('sdu_univ.xls')
df15=pd.read_excel('sdu1.xls')
df16=pd.read_excel('sdu2.xls')
df17=pd.read_excel('sdu2170.xls')

fdf=pd.concat([df,df14], ignore_index=True)
tdf = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df125, df126, df137], ignore_index=True)

# %%
fdf.columns
# Out:
# Index(['Publication Type', 'Authors', 'Book Authors', 'Group Authors',
#        'Book Group Authors', 'Researcher Ids', 'ORCIDs', 'Book Editors',
#        'Author - Arabic', 'Grant Principal Investigator',
#        'Grant Co Principal Investigator', 'Article Title',
#        'Article Title - SciELO', 'Article Title - SciELO.1',
#        'Article Title - Chinese', 'Article Title - Russian', 'Patent Number',
#        'Patent Assignee', 'Source Title - Arabic', 'Source Title',
#        'Source Title - Korean', 'Book Series Title', 'Book Series Subtitle',
#        'Volume', 'Issue', 'Special Issue', 'Meeting Abstract', 'Start Page',
#        'End Page', 'Article Number', 'Version', 'Version History', 'DOI',
#        'Book DOI', 'License Name', 'License URI', 'License Description',
#        'Early Access Date', 'Supplement', 'Document Type', 'Publication Date',
#        'Publication Year', 'Abstract', 'Abstract - Foreign',
# ...

# %%
fdf.to_csv('fdf.csv', index=False)

tdf.to_csv('tdf.csv', index=False)

# %%
tdf.columns
# Out:
# Index(['Publication Type', 'Authors', 'Book Authors', 'Group Authors',
#        'Book Group Authors', 'Researcher Ids', 'ORCIDs', 'Book Editors',
#        'Author - Arabic', 'Grant Principal Investigator',
#        'Grant Co Principal Investigator', 'Article Title',
#        'Article Title - SciELO', 'Article Title - SciELO.1',
#        'Article Title - Chinese', 'Article Title - Russian', 'Patent Number',
#        'Patent Assignee', 'Source Title - Arabic', 'Source Title',
#        'Source Title - Korean', 'Book Series Title', 'Book Series Subtitle',
#        'Volume', 'Issue', 'Special Issue', 'Meeting Abstract', 'Start Page',
#        'End Page', 'Article Number', 'Version', 'Version History', 'DOI',
#        'Book DOI', 'License Name', 'License URI', 'License Description',
#        'Early Access Date', 'Supplement', 'Document Type', 'Publication Date',
#        'Publication Year', 'Abstract', 'Abstract - Foreign',
# ...

# %%
import pandas as pd
df=pd.read_csv('fdf.csv')
df.columns
# Out:
# Index(['Publication Type', 'Authors', 'Book Authors', 'Group Authors',
#        'Book Group Authors', 'Researcher Ids', 'ORCIDs', 'Book Editors',
#        'Author - Arabic', 'Grant Principal Investigator',
#        'Grant Co Principal Investigator', 'Article Title',
#        'Article Title - SciELO', 'Article Title - SciELO.1',
#        'Article Title - Chinese', 'Article Title - Russian', 'Patent Number',
#        'Patent Assignee', 'Source Title - Arabic', 'Source Title',
#        'Source Title - Korean', 'Book Series Title', 'Book Series Subtitle',
#        'Volume', 'Issue', 'Special Issue', 'Meeting Abstract', 'Start Page',
#        'End Page', 'Article Number', 'Version', 'Version History', 'DOI',
#        'Book DOI', 'License Name', 'License URI', 'License Description',
#        'Early Access Date', 'Supplement', 'Document Type', 'Publication Date',
#        'Publication Year', 'Abstract', 'Abstract - Foreign',
# ...

# %%
important_cols = [
"Article Title",
"Authors",
"Publication Year",
"Source Title",
"Document Type",
"DOI",
"Times Cited, All Databases",
"UT (Unique ID)",
"Abstract",
"Author Keywords",
"Institution Address",
"Institution"
]

df[important_cols].head()
# Out:
#                                        Article Title  \
# 0  Speak Kazakh: Language Ideologies in Kazakhsta...
# 1  University-industry knowledge transfer in an e...
# 2  Modeling tuberculosis transmission dynamics in...
# 3  Awareness of Autism Spectrum Disorder Among Po...
# 4  Content and language integrated learning in Ka...
#
#                                              Authors  Publication Year  \
# 0                                    Kamalova, Alina              2025
# 1                                Smirnova, Yelena V.              2016
# 2  Kalizhanova, Aigerim; Yerdessov, Sauran; Sakko...              2024
# 3  Kurmanalina, Sandugash; Samambayeva, Aizhan; A...              2025
# 4  Satayev, Malik; Varis, Sotiria; Ashirbayev, Ye...              2025
#
#                                         Source Title Document Type  \
# 0                        JOURNAL OF SOCIOLINGUISTICS       Article
# 1                          SCIENCE AND PUBLIC POLICY       Article
# ...

# %%
df["Times Cited, All Databases"].sum()
# Out:
# np.int64(4161)
